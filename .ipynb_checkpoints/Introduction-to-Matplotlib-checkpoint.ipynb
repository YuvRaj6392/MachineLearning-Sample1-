# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4],[10,200,30000,400000]);

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)

# %%
fig, ax=plt.subplots()
ax.plot(x,y)
