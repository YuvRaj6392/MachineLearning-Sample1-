# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4],[10,200,30000,400000]);

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)

# %%
fig, ax=plt.subplots()
ax.plot(x,y)

# %% [markdown]
# ## Anatomy of a figure

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with numpy array

# %%
import numpy as np

# %%
x=np.linspace(0,100,100)

# %%
x[:10]
# Out:
# array([0.        , 1.01010101, 2.02020202, 3.03030303, 4.04040404,
#        5.05050505, 6.06060606, 7.07070707, 8.08080808, 9.09090909])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,x**2)

# %%
butter={"almond":34,
        "butter":45,
       "chocolate":12}

# %%
fig,ax=plt.subplots()
ax.bar(butter.keys(),height=butter.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Multiple subplots

# %%
fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                      ncols=2,
                                      figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(x,x**2)
ax4.hist(np.random.randn(1000))
# Out:
# (array([ 11.,  40., 127., 218., 248., 198., 110.,  33.,  14.,   1.]),
#  array([-2.67790522, -2.06674953, -1.45559384, -0.84443816, -0.23328247,
#          0.37787322,  0.98902891,  1.60018459,  2.21134028,  2.82249597,
#          3.43365166]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Different way to create subplot

# %%
fig, ax=plt.subplots(nrows=2,
                     ncols=2,
                     figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[1,1].scatter(np.random.rand(10),np.random.rand(10))

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd

# %%
ts=pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2020",
                                 periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Plotting from Pandas DataFrame2

# %%
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,.]', '', regex=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
# Remove the last 2 zeros

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2020",periods=(len(car_sales)))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"]=car_sales["Price"].astype(int).cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Sale Date",y="Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %%
car_sales["Price"]=car_sales["Price"].astype(int)

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# what about bar graph?

# %%
x=np.random.rand(5,4)

# %%
df=pd.DataFrame(x,columns=('a','b','c','d'))
df
# Out:
#           a         b         c         d
# 0  0.335498  0.470607  0.933953  0.918610
# 1  0.331630  0.740267  0.558499  0.738352
# 2  0.763858  0.350923  0.544901  0.603086
# 3  0.308175  0.731841  0.946246  0.357059
# 4  0.019160  0.430962  0.729019  0.647163

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make",y="Odometer (KM)", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
#What about historgrams

# %%
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## On another dataset

# %%
heart_disease=pd.read_csv("heart-disease.csv")

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## Creating a histogram out of it

# %%
heart_disease["age"].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# ## Plotting for dataFrame 5

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
age_50=heart_disease[heart_disease["age"]>50]

# %%
age_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
age_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
fig, ax=plt.subplots(figsize=(10,6))
age_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax)
ax.set_xlim([45,100])
ax.set_ylim([50,350])
# Out:
# (50.0, 350.0)

# %% [markdown]
# ## Data Frame 6

# %%
age_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
fig,ax=plt.subplots(figsize=(10,6))
scatter=ax.scatter(x=age_50["age"],
                   y=age_50["chol"],
                   c=age_50["target"],
                  cmap="winter")
ax.set(title="Heart Disease",
       xlabel="Age",
       ylabel="Chol")
ax.legend(*scatter.legend_elements(),title="Target")
ax.axhline(age_50["chol"].mean(),linestyle="--")

# %% [markdown]
# ## Adding style to plot

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('dark_background')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
x=np.random.randn(10,4)

# %%
x
# Out:
# array([[ 0.4935123 ,  1.40001389, -0.29863828,  0.55470858],
#        [ 0.95405768, -1.27165422, -0.23955096,  1.12927724],
#        [ 0.00683159, -0.26358296,  0.69758784,  0.18428144],
#        [ 0.95737691, -1.00266634, -1.54815986,  0.98445332],
#        [-0.13613268,  0.18925199, -0.16086313,  0.58694782],
#        [ 1.24775711, -1.02672335, -0.84742615, -1.35524219],
#        [-0.48807857, -0.4264031 , -0.31173986, -1.7172755 ],
#        [-0.92964283,  0.47088013, -1.17295742, -0.1187389 ],
#        [-0.48691012,  0.58276283,  0.64254631,  0.54050445],
#        [ 0.16446512,  0.19238889,  1.14659452,  1.13209731]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.493512  1.400014 -0.298638  0.554709
# 1  0.954058 -1.271654 -0.239551  1.129277
# 2  0.006832 -0.263583  0.697588  0.184281
# 3  0.957377 -1.002666 -1.548160  0.984453
# 4 -0.136133  0.189252 -0.160863  0.586948
# 5  1.247757 -1.026723 -0.847426 -1.355242
# 6 -0.488079 -0.426403 -0.311740 -1.717275
# 7 -0.929643  0.470880 -1.172957 -0.118739
# 8 -0.486910  0.582763  0.642546  0.540504
# 9  0.164465  0.192389  1.146595  1.132097

# %%
ax=df.plot(kind="bar")
