# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4],[10,200,30000,400000]);

# %%
x=[1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)

# %%
fig, ax=plt.subplots()
ax.plot(x,y)

# %% [markdown]
# ## Anatomy of a figure

# %%
x=[1,2,3,4]
y=[11,22,33,44]

# %%
fig,ax=plt.subplots(figsize=(10,10))
ax.plot(x,y)
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with numpy array

# %%
import numpy as np

# %%
x=np.linspace(0,100,100)

# %%
x[:10]
# Out:
# array([0.        , 1.01010101, 2.02020202, 3.03030303, 4.04040404,
#        5.05050505, 6.06060606, 7.07070707, 8.08080808, 9.09090909])

# %%
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,x**2)

# %%
butter={"almond":34,
        "butter":45,
       "chocolate":12}

# %%
fig,ax=plt.subplots()
ax.bar(butter.keys(),height=butter.values())
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Multiple subplots

# %%
fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                      ncols=2,
                                      figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(x,x**2)
ax4.hist(np.random.randn(1000))
# Out:
# (array([  2.,  20.,  60., 153., 257., 268., 163.,  59.,  15.,   3.]),
#  array([-3.72160196, -2.97273156, -2.22386117, -1.47499077, -0.72612038,
#          0.02275002,  0.77162041,  1.52049081,  2.26936121,  3.0182316 ,
#          3.767102  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Different way to create subplot

# %%
fig, ax=plt.subplots(nrows=2,
                     ncols=2,
                     figsize=(10,5))
ax[0,0].plot(x,x/2)
ax[1,1].scatter(np.random.rand(10),np.random.rand(10))

# %% [markdown]
# ## Plotting from pandas DataFrame

# %%
import pandas as pd

# %%
ts=pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2020",
                                 periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >
